# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sas

# %%
df=pd.read_csv('C:/Users/Rajnish Chanchal/Downloads/deliveries.csv')

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# indepth analysis of David Warner Performance

# %%
filt=df['batsman']=='DA Warner'
df_warner=df[filt]
df_warner.shape
# Out:
# (2902, 21)

# %%
df_warner['dismissal_kind'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %%
len(df_warner[df_warner['batsman_runs']==6])
# Out:
# 160

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs

# %%
count(df_warner,1)
# Out:
# 997

# %%
count(df_warner,2)
# Out:
# 414

# %%
count(df_warner,3)
# Out:
# 39

# %%
count(df_warner,4)
# Out:
# 1604

# %%
count(df_warner,6)
# Out:
# 960

# %%
slices=[997,414,39,1604,960]
label=[1,2,3,4,6]
plt.pie(slices,labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x19098a5ab50>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.0200956448131961, -0.4115882352948756, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')])

# %%
plt.pie(slices,labels=label,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19098aaa790>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.0200956448131961, -0.4115882352948756, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.5564158062617433, -0.22450267379720487, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
explode=[0,0,0,0.1,0]
plt.pie(slices,labels=label,autopct='%1.1f%%',explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x19098b05a60>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.1128316125234867, -0.44900534759440974, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.6491517739720338, -0.261919786096739, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
# Score Distribution for teams by innings

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
teams={
    'Royal Challengers Bangalore':'RCB', 'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS', 'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 'Gujarat Lions':'GL', 'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD', 'Chennai Super Kings':'CSK', 'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC', 'Kochi Tuskers Kerala':'KTK', 'Pune Warriors':'PW'
}

# %%
df['batting_team']=df['batting_team'].map(teams)
df['bowling_team']=df['bowling_team'].map(teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
# Out:
# match_id  inning  batting_team
# 1         1       SRH             207
#           2       RCB             172
# 2         1       MI              184
#           2       RPS             187
# 3         1       GL              183
#                                  ...
# 634       2       KKR             140
# 635       1       GL              162
#           2       SRH             163
# 636       1       SRH             208
#           2       RCB             200
# Name: total_runs, Length: 1270, dtype: int64

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          SRH         207
# 1            1       2          RCB         172
# 2            2       1           MI         184
# 3            2       2          RPS         187
# 4            3       1           GL         183
# ...        ...     ...          ...         ...
# 1265       634       2          KKR         140
# 1266       635       1           GL         162
# 1267       635       2          SRH         163
# 1268       636       1          SRH         208
# 1269       636       2          RCB         200
#
# [1270 rows x 4 columns]

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id',axis=1,inplace=True)
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           GL         183
# ...      ...          ...         ...
# 1265       2          KKR         140
# 1266       1           GL         162
# 1267       2          SRH         163
# 1268       1          SRH         208
# 1269       2          RCB         200
#
# [1270 rows x 3 columns]

# %%
inning1=runs[runs['inning']==1]
inning2=runs[runs['inning']==2]
sas.boxplot(x='batting_team',y='total_runs',data=inning1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
sas.boxplot(x='batting_team',y='total_runs',data=inning2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
# How many teams score more than 200

# %%
high_score=df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum()
high_score
# Out:
# match_id  inning  batting_team  bowling_team
# 1         1       SRH           RCB             207
#           2       RCB           SRH             172
# 2         1       MI            RPS             184
#           2       RPS           MI              187
# 3         1       GL            KKR             183
#                                                ...
# 634       2       KKR           SRH             140
# 635       1       GL            SRH             162
#           2       SRH           GL              163
# 636       1       SRH           RCB             208
#           2       RCB           SRH             200
# Name: total_runs, Length: 1256, dtype: int64

# %%
high_score=high_score.reset_index()
high_score
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           GL          KKR         183
# ...        ...     ...          ...          ...         ...
# 1251       634       2          KKR          SRH         140
# 1252       635       1           GL          SRH         162
# 1253       635       2          SRH           GL         163
# 1254       636       1          SRH          RCB         208
# 1255       636       2          RCB          SRH         200
#
# [1256 rows x 5 columns]

# %%
score_200=high_score[high_score["total_runs"]>=200]
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           GL         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1228       620       1          RCB           GL         248
# 1232       623       1           MI           DD         206
# 1236       626       1          RCB         KXIP         211
# 1254       636       1          SRH          RCB         208
# 1255       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %%
sas.countplot(score_200['batting_team'])
# Out:
# C:\Users\Rajnish Chanchal\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='batting_team', ylabel='count'>

# %%
sas.countplot(score_200['bowling_team'])
# Out:
# C:\Users\Rajnish Chanchal\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bowling_team', ylabel='count'>

# %%
# Batsman Comparison
# 1. Top 10 Batsman
# 2. Top Individual Scores Batsman
# 3. Highest Wicket Taker

# %%
top_batsman=df.groupby(['batsman'])['total_runs'].sum().reset_index()
top_batsman
# Out:
#             batsman  total_runs
# 0    A Ashish Reddy         288
# 1        A Chandila           4
# 2          A Chopra          58
# 3       A Choudhary          25
# 4        A Flintoff          72
# ..              ...         ...
# 456     YV Takawale         207
# 457   Yashpal Singh          49
# 458     Younis Khan           3
# 459    Yuvraj Singh        2710
# 460          Z Khan         121
#
# [461 rows x 2 columns]

# %%
top_batsman=top_batsman.sort_values(by=['total_runs'],ascending=False)
top_batsman.head(10)
# Out:
#             batsman  total_runs
# 374        SK Raina        4745
# 431         V Kohli        4588
# 137       G Gambhir        4388
# 323       RG Sharma        4334
# 103       DA Warner        4213
# 340      RV Uthappa        4004
# 85         CH Gayle        3914
# 347        S Dhawan        3754
# 259        MS Dhoni        3728
# 22   AB de Villiers        3621

# %%
runs=df.groupby(['batsman'])['batsman_runs'].sum().reset_index()
runs.columns=['batsman','batsman_runs']
runs
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
balls=df.groupby(['batsman'])['ball'].count().reset_index()
balls.columns=['batsman','balls']
balls
# Out:
#             batsman  balls
# 0    A Ashish Reddy    196
# 1        A Chandila      7
# 2          A Chopra     75
# 3       A Choudhary     20
# 4        A Flintoff     57
# ..              ...    ...
# 456     YV Takawale    183
# 457   Yashpal Singh     67
# 458     Younis Khan      7
# 459    Yuvraj Singh   2050
# 460          Z Khan    141
#
# [461 rows x 2 columns]

# %%
four=df[df['batsman_runs']==4]
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          RCB     1     3      DA Warner
# 8              1       1          SRH          RCB     2     2      DA Warner
# 13             1       1          SRH          RCB     2     7   MC Henriques
# 30             1       1          SRH          RCB     5     5   MC Henriques
# 32             1       1          SRH          RCB     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB          SRH    11     4        V Kohli
# 150407       636       2          RCB          SRH    12     2        V Kohli
# 150418       636       2          RCB          SRH    14     1       KL Rahul
# 150447       636       2          RCB          SRH    18     6    Sachin Baby
# 150459       636       2          RCB          SRH    20     6  Iqbal Abdulla
#
# ...

# %%
six=df[df['batsman_runs']==6]
six
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10             1       1          SRH          RCB     2     4     DA Warner
# 47             1       1          SRH          RCB     8     4  MC Henriques
# 75             1       1          SRH          RCB    13     2  Yuvraj Singh
# 89             1       1          SRH          RCB    15     3  Yuvraj Singh
# 91             1       1          SRH          RCB    15     5  MC Henriques
# ...          ...     ...          ...          ...   ...   ...           ...
# 150395       636       2          RCB          SRH    10     2       V Kohli
# 150413       636       2          RCB          SRH    13     2       V Kohli
# 150428       636       2          RCB          SRH    15     5     SR Watson
# 150440       636       2          RCB          SRH    17     5     STR Binny
# 150453       636       2          RCB          SRH    19     6   Sachin Baby
#
# ...

# %%
runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
runs_6=six.groupby('batsman')['batsman_runs'].count().reset_index()
runs_6.columns=['batsman','6s']
runs_6
# Out:
#              batsman   6s
# 0     A Ashish Reddy   15
# 1        A Choudhary    1
# 2         A Flintoff    2
# 3           A Mishra    5
# 4           A Mithun    1
# ..               ...  ...
# 296  Y Venugopal Rao   37
# 297        YK Pathan  149
# 298      YV Takawale    3
# 299     Yuvraj Singh  141
# 300           Z Khan    2
#
# [301 rows x 2 columns]

# %%
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],runs_6.iloc[:,1]],axis=1)
player
# Out:
#             batsman  batsman_runs  balls    4s    6s
# 0    A Ashish Reddy           280    196  16.0  15.0
# 1        A Chandila             4      7   7.0   1.0
# 2          A Chopra            53     75   1.0   2.0
# 3       A Choudhary            25     20   5.0   5.0
# 4        A Flintoff            62     57   3.0   1.0
# ..              ...           ...    ...   ...   ...
# 456     YV Takawale           192    183   NaN   NaN
# 457   Yashpal Singh            47     67   NaN   NaN
# 458     Younis Khan             3      7   NaN   NaN
# 459    Yuvraj Singh          2591   2050   NaN   NaN
# 460          Z Khan           117    141   NaN   NaN
#
# [461 rows x 5 columns]

# %%
player.fillna(0,inplace=True)
player
# Out:
#             batsman  batsman_runs  balls    4s    6s
# 0    A Ashish Reddy           280    196  16.0  15.0
# 1        A Chandila             4      7   7.0   1.0
# 2          A Chopra            53     75   1.0   2.0
# 3       A Choudhary            25     20   5.0   5.0
# 4        A Flintoff            62     57   3.0   1.0
# ..              ...           ...    ...   ...   ...
# 456     YV Takawale           192    183   0.0   0.0
# 457   Yashpal Singh            47     67   0.0   0.0
# 458     Younis Khan             3      7   0.0   0.0
# 459    Yuvraj Singh          2591   2050   0.0   0.0
# 460          Z Khan           117    141   0.0   0.0
#
# [461 rows x 5 columns]

# %%
player['strike_rate']=(player['batsman_runs']/player['balls'])*100
player
# Out:
#             batsman  batsman_runs  balls    4s    6s  strike_rate
# 0    A Ashish Reddy           280    196  16.0  15.0   142.857143
# 1        A Chandila             4      7   7.0   1.0    57.142857
# 2          A Chopra            53     75   1.0   2.0    70.666667
# 3       A Choudhary            25     20   5.0   5.0   125.000000
# 4        A Flintoff            62     57   3.0   1.0   108.771930
# ..              ...           ...    ...   ...   ...          ...
# 456     YV Takawale           192    183   0.0   0.0   104.918033
# 457   Yashpal Singh            47     67   0.0   0.0    70.149254
# 458     Younis Khan             3      7   0.0   0.0    42.857143
# 459    Yuvraj Singh          2591   2050   0.0   0.0   126.390244
# 460          Z Khan           117    141   0.0   0.0    82.978723
#
# [461 rows x 6 columns]

# %%
grp=df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9419       636     SR Watson          RCB            11
# 9420       636     STR Binny          RCB             9
# 9421       636   Sachin Baby          RCB            18
# 9422       636       V Kohli          RCB            54
# 9423       636  Yuvraj Singh          SRH            38
#
# [9424 rows x 4 columns]

# %%
max_by_each=grp.groupby('batsman')['batsman_runs'].max().reset_index()
max_by_each.columns=['batsman','max_runs']
max_by_each
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 453     YV Takawale        45
# 454   Yashpal Singh        20
# 455     Younis Khan         3
# 456    Yuvraj Singh        83
# 457          Z Khan        23
#
# [458 rows x 2 columns]

# %%
player2=pd.concat([player,max_by_each.iloc[:,1]],axis=1)
player2
# Out:
#             batsman  batsman_runs  balls    4s    6s  strike_rate  max_runs
# 0    A Ashish Reddy           280    196  16.0  15.0   142.857143      36.0
# 1        A Chandila             4      7   7.0   1.0    57.142857       4.0
# 2          A Chopra            53     75   1.0   2.0    70.666667      24.0
# 3       A Choudhary            25     20   5.0   5.0   125.000000      15.0
# 4        A Flintoff            62     57   3.0   1.0   108.771930      24.0
# ..              ...           ...    ...   ...   ...          ...       ...
# 456     YV Takawale           192    183   0.0   0.0   104.918033      83.0
# 457   Yashpal Singh            47     67   0.0   0.0    70.149254      23.0
# 458     Younis Khan             3      7   0.0   0.0    42.857143       NaN
# 459    Yuvraj Singh          2591   2050   0.0   0.0   126.390244       NaN
# 460          Z Khan           117    141   0.0   0.0    82.978723       NaN
#
# [461 rows x 7 columns]

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='batsman'>

# %%
df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9185       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds=['caught','bowled','lbw','caught and bowled','stumped','hit wicket']

# %%
hwt=df[df['dismissal_kind'].isin(dismissal_kinds)]
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          RCB     2     5      DA Warner
# 64          1       1          SRH          RCB    11     3       S Dhawan
# 94          1       1          SRH          RCB    16     2   MC Henriques
# 116         1       1          SRH          RCB    19     4   Yuvraj Singh
# 160         1       2          RCB          SRH     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
hwt['bowler'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>
